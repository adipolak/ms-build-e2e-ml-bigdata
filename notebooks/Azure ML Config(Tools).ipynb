# %%
# Authenticate with Azure ML
from azureml.core.authentication import ServicePrincipalAuthentication
from azureml.core import Workspace

# @TODO Move to DB Secrets
sp_auth = ServicePrincipalAuthentication(tenant_id="72f988bf-86f1-41af-91ab-2d7cd011db47", # tenantID
                                    service_principal_id="219640dd-937c-44ee-b00e-01b319e97e24", # clientId
                                    service_principal_password="]N0Q685tdMFpUQ-pdyl.sZCHKfBE[1fW") # clientSecret
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Load AML Workspace
ws = Workspace(
  subscription_id="6560575d-fa06-4e7d-95fb-f962e74efd7a",
  resource_group="build-e2e-ml-bigdata",
  workspace_name="ml-e2e-bigdata-mls",
  auth=sp_auth
)

# Write config file to ease later access
ws.write_config()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
