# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Fschema = StructType([
  StructField("file_index", StringType(), True),
  StructField("text", StringType(), True),
  StructField("id", StringType(), True),
  StructField("subreddit", StringType(), True),
  StructField("meta", StringType(), True),
  StructField("time", FloatType(), True),
  StructField("author", StringType(), True),
  StructField("ups", FloatType(), True),
  StructField("downs", FloatType(), True),
  StructField("authorlinkkarma", FloatType(), True),
  StructField("authorkarma", FloatType(), True),
  StructField("authorisgold", FloatType(), True)
])
  
df = spark.read.csv("/mnt/test/*.csv", schema=Fschema, header=True)

# cast boolean
df = df.withColumn(
  "authorisgold",
  when(df.authorisgold == '0.0', 0).when(df.authorisgold == '1.0', 1).otherwise(0)
)
df = df.withColumn("authorisgold", df["authorisgold"].cast("boolean"))

# drop file index
df = df.drop("file_index")

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>text</th><th>id</th><th>subreddit</th><th>meta</th><th>time</th><th>author</th><th>ups</th><th>downs</th><th>authorlinkkarma</th><th>authorkarma</th><th>authorisgold</th></tr></thead><tbody><tr><td>i am referring to  this   http  iimgurcom5srylmijpg  does it have any deeper meaning or does it signify anything  i just do nt get it why she d do that</td><td>466ijy</td><td>anime</td><td>entertainment</td><td>1.45568282E9</td><td>shiba_arata</td><td>0.0</td><td>0.0</td><td>1.0</td><td>20.0</td><td>false</td></tr><tr><td>cheating but zoldycks must have a great time at thanksgiving</td><td>d02g879</td><td>anime</td><td>entertainment</td><td>1.45566118E9</td><td>ShaKing807</td><td>6.0</td><td>0.0</td><td>1308.0</td><td>62021.0</td><td>true</td></tr><tr><td>kurosaki ichigo    http  images5fanpopcomimagephotos29000000ichigowallpaperkurosakiichigo290694271024768jpg  and  kurosaki mea   http  staticzerochannetkurosakimeafull1689483jpg</td><td>d02v88z</td><td>anime</td><td>entertainment</td><td>1.45568499E9</td><td>Tf2idlingftw</td><td>2.0</td><td>0.0</td><td>4156.0</td><td>1021.0</td><td>false</td></tr><tr><td>there are a shit ton of koutarous  but the presence of  one   https  smediacacheak0pinimgcomoriginals1219ed1219ed717fc2bfce372759bba2fe1cfegif  is enough to make it the most interesting party</td><td>d02ggn7</td><td>anime</td><td>entertainment</td><td>1.45566157E9</td><td>Angst-Incarnate</td><td>1.0</td><td>0.0</td><td>137.0</td><td>41859.0</td><td>false</td></tr><tr><td>they went full free in the end</td><td>d0280d1</td><td>anime</td><td>entertainment</td><td>1.4556503E9</td><td>ASK-ME-IF-I-DID-IT</td><td>7.0</td><td>0.0</td><td>1154.0</td><td>8941.0</td><td>false</td></tr><tr><td>by far the best episode of this show this was pure fun to watch from beginning to end</td><td>d02307g</td><td>anime</td><td>entertainment</td><td>1.45564352E9</td><td>Smudy</td><td>2.0</td><td>0.0</td><td>740.0</td><td>4325.0</td><td>false</td></tr><tr><td>gal stan might as well be team durarara with masaomi  mikado  and rochi</td><td>d026ijg</td><td>anime</td><td>entertainment</td><td>1.45564826E9</td><td>Russiandragon55</td><td>3.0</td><td>0.0</td><td>1000.0</td><td>605.0</td><td>false</td></tr><tr><td>hi th3jester_  it seems like you might be looking for anime recommendations  the users of this subreddit came up with  an awesome recommendations flowchart   http  iimgurcomq9xjv4pjpg   maybe you can find something there that you ll like         botchan  urban ssssenpai made me do it    you might also find our  recommendation wiki   http  wwwredditcomranimewikirecommendations  helpful  the following may be of interest    list of legal streams and downloads   https  wwwredditcomranimewikilegal_streams__downloads    list of currently airing anime   https  wwwlivechartme   i am a bot  and this action was performed automatically please  contact the moderators of this subreddit   messagecompose  to  ranime  if you have any questions or concerns</td><td>d020243</td><td>anime</td><td>entertainment</td><td>1.4556393E9</td><td>AutoModerator</td><td>19.0</td><td>0.0</td><td>1476.0</td><td>278459.0</td><td>true</td></tr><tr><td>related    shounen sarutobi sasuke  aka  magic boy    https  wwwyoutubecomwatch  v  yohgqmnskis</td><td>d029srr</td><td>anime</td><td>entertainment</td><td>1.45565261E9</td><td>_F1_</td><td>2.0</td><td>0.0</td><td>2543.0</td><td>65930.0</td><td>false</td></tr><tr><td>uchuu senkan yamato looks interesting</td><td>d02f5bq</td><td>anime</td><td>entertainment</td><td>1.45565978E9</td><td>kikoano</td><td>2.0</td><td>0.0</td><td>2779.0</td><td>1513.0</td><td>false</td></tr><tr><td>gt  the series was a huge sensation despite the fact that nothing beyond the first season aired on american television until later the pause was due primarily to censorship issues  cartoons were seen purely as a children  s medium whose audience  accordi ...

# %%
display(df.limit(100))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>text</th><th>id</th><th>subreddit</th><th>meta</th><th>time</th><th>author</th><th>ups</th><th>downs</th><th>authorlinkkarma</th><th>authorkarma</th><th>authorisgold</th></tr></thead><tbody><tr><td>i am referring to  this   http  iimgurcom5srylmijpg  does it have any deeper meaning or does it signify anything  i just do nt get it why she d do that</td><td>466ijy</td><td>anime</td><td>entertainment</td><td>1.45568282E9</td><td>shiba_arata</td><td>0.0</td><td>0.0</td><td>1.0</td><td>20.0</td><td>false</td></tr><tr><td>cheating but zoldycks must have a great time at thanksgiving</td><td>d02g879</td><td>anime</td><td>entertainment</td><td>1.45566118E9</td><td>ShaKing807</td><td>6.0</td><td>0.0</td><td>1308.0</td><td>62021.0</td><td>true</td></tr><tr><td>kurosaki ichigo    http  images5fanpopcomimagephotos29000000ichigowallpaperkurosakiichigo290694271024768jpg  and  kurosaki mea   http  staticzerochannetkurosakimeafull1689483jpg</td><td>d02v88z</td><td>anime</td><td>entertainment</td><td>1.45568499E9</td><td>Tf2idlingftw</td><td>2.0</td><td>0.0</td><td>4156.0</td><td>1021.0</td><td>false</td></tr><tr><td>there are a shit ton of koutarous  but the presence of  one   https  smediacacheak0pinimgcomoriginals1219ed1219ed717fc2bfce372759bba2fe1cfegif  is enough to make it the most interesting party</td><td>d02ggn7</td><td>anime</td><td>entertainment</td><td>1.45566157E9</td><td>Angst-Incarnate</td><td>1.0</td><td>0.0</td><td>137.0</td><td>41859.0</td><td>false</td></tr><tr><td>they went full free in the end</td><td>d0280d1</td><td>anime</td><td>entertainment</td><td>1.4556503E9</td><td>ASK-ME-IF-I-DID-IT</td><td>7.0</td><td>0.0</td><td>1154.0</td><td>8941.0</td><td>false</td></tr><tr><td>by far the best episode of this show this was pure fun to watch from beginning to end</td><td>d02307g</td><td>anime</td><td>entertainment</td><td>1.45564352E9</td><td>Smudy</td><td>2.0</td><td>0.0</td><td>740.0</td><td>4325.0</td><td>false</td></tr><tr><td>gal stan might as well be team durarara with masaomi  mikado  and rochi</td><td>d026ijg</td><td>anime</td><td>entertainment</td><td>1.45564826E9</td><td>Russiandragon55</td><td>3.0</td><td>0.0</td><td>1000.0</td><td>605.0</td><td>false</td></tr><tr><td>hi th3jester_  it seems like you might be looking for anime recommendations  the users of this subreddit came up with  an awesome recommendations flowchart   http  iimgurcomq9xjv4pjpg   maybe you can find something there that you ll like         botchan  urban ssssenpai made me do it    you might also find our  recommendation wiki   http  wwwredditcomranimewikirecommendations  helpful  the following may be of interest    list of legal streams and downloads   https  wwwredditcomranimewikilegal_streams__downloads    list of currently airing anime   https  wwwlivechartme   i am a bot  and this action was performed automatically please  contact the moderators of this subreddit   messagecompose  to  ranime  if you have any questions or concerns</td><td>d020243</td><td>anime</td><td>entertainment</td><td>1.4556393E9</td><td>AutoModerator</td><td>19.0</td><td>0.0</td><td>1476.0</td><td>278459.0</td><td>true</td></tr><tr><td>related    shounen sarutobi sasuke  aka  magic boy    https  wwwyoutubecomwatch  v  yohgqmnskis</td><td>d029srr</td><td>anime</td><td>entertainment</td><td>1.45565261E9</td><td>_F1_</td><td>2.0</td><td>0.0</td><td>2543.0</td><td>65930.0</td><td>false</td></tr><tr><td>uchuu senkan yamato looks interesting</td><td>d02f5bq</td><td>anime</td><td>entertainment</td><td>1.45565978E9</td><td>kikoano</td><td>2.0</td><td>0.0</td><td>2779.0</td><td>1513.0</td><td>false</td></tr><tr><td>gt  the series was a huge sensation despite the fact that nothing beyond the first season aired on american television until later the pause was due primarily to censorship issues  cartoons were seen purely as a children  s medium whose audience  accordi ...

# %%
# Write to storage in parquet format
df \
  .write \
  .partitionBy("subreddit") \
  .option("compression","none") \
  .mode('append') \
  .parquet(dbfs_mnt_processed + "/redditcomments/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
